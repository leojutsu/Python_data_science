# %% [markdown]
# <a href="https://colab.research.google.com/github/leojutsu/Python_data_science/blob/main/Ex_Regress%C3%A3o_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
# Carregar o dataset diabetes
diabetes = load_diabetes()

# %%
# Dividir os dados em conjuntos de treino e teste
X_train, X_test, y_train, y_test = train_test_split(diabetes.data, diabetes.target, test_size=0.2, random_state=42)

# %%
# Criando um instância no modelo de regressão linear
lr = LinearRegression()

# %%
# Treinando o modelo com os dados de treino
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
#Fazendo previsões com os dados de teste
y_pred = lr.predict(X_test)

# %%
# Plotando os resultados
plt.scatter(y_test, y_pred)
plt.xlabel("True Values")
plt.ylabel("Predictions")
plt.show()
